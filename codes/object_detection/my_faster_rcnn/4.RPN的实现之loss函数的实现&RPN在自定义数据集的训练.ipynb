# %% [markdown]
# # RPN的实现之loss函数的实现&RPN在自定义数据集的训练

# %% [markdown]
# RPN loss:
#
# $RPNLoss=Classification Loss + Bounding Box Loss$

# %% [markdown]
# Classification Loss(分类损失)：
# ![classification_loss.png](attachment:classification_loss.png)
